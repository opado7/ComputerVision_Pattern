# %% [markdown]
# 논문
# 0. Abstraction
# 1. Introduction(서론)
# 2. Related Work(관련 연구)
# 3. System. Proposed model(본론)
#   - 읽어야 할 논문의 자세한 부분
#   - 3번에 메인 그림이 하나씩 있는데 이것을 참고하면 좋음
# 4. Experimental Result(실험 결과)
#   - 논문이 올라왔다는건 글쓴이가 결과를 좋게 도출하도록 유도했을 가능성이 있으므로 급하다면 건너뛰어도 무방함
# 5. Conclusion(결론)
#
# Abstraction → conclusion / introduction → 그 외
#
# Related Workd → 제외가능
#
# - Evaluation
# - Validation

# %% [markdown]
# NasNet
# - 과거의 정보가 미래에 반영됨
# - 신경망 아키텍처의 구조를 자동으로 탐색하고 최적의 구조를 찾아내기 위해 강화학습과 경사도 기반 최적화를 조합
# - 기존에 사용하던 합성곱 층과는 다르게 깊이 분리 가능한 합성곱을 사용
# $$\frac{1}{N}+\frac{1}{D^2_K}$$
# $\frac{1}{N}=$필터의 개수

# %%
# !gdown 1WI3FPChY3DFnrNEP3Fk_C61bcMxkr4-b

# %%
import tensorflow as tf
from tensorflow.keras.application import EfficientNetB0
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input, decode_predictions

# 이피션트넷 모델 불러오기
efficientnet_model = EfficientNetB0(weights='imagenet', include_top = True)
efficientnet_model.summary()

# %% [markdown]
# RNN, LSTM, GRU
# - 한번씩만 찾아보기
